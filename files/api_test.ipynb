# %%
import requests
from datetime import date

BASE_URL = "http://localhost:8000"

def test_health():
    r = requests.get(f"{BASE_URL}/health")
    print("HEALTH:", r.status_code, r.json())


def test_pairs():
    r = requests.get(f"{BASE_URL}/pairs")
    print("PAIRS:", r.status_code, r.json())


def test_history():
    params = {
        "start": "2024-01-01",
        "end": "2025-01-01"
    }
    pair = "EUR/USD"  # замени на реальный ключ из PAIRS
    r = requests.get(f"{BASE_URL}/history/{pair}", params=params)
    print("HISTORY:", r.status_code, r.json()[:2])


def test_context():
    params = {
        "start": "2024-01-01",
        "end": "2025-01-01"
    }
    pair = "EUR/USD"
    r = requests.get(f"{BASE_URL}/context/{pair}", params=params)
    print("CONTEXT:", r.status_code, r.json()[:2])


def test_predictions():
    params = {
        "start": "2024-01-01",
        "end": "2025-01-01",
        "limit": 10
    }
    pair = "EUR/USD"
    r = requests.get(f"{BASE_URL}/predictions/{pair}", params=params)
    print("PREDICTIONS:", r.status_code, r.json()[:2])


def test_latest():
    pair = "EUR/USD"
    r = requests.get(f"{BASE_URL}/latest/{pair}")
    print("LATEST:", r.status_code, r.json())


def test_etl_stats():
    r = requests.get(f"{BASE_URL}/etl/stats", params={"days": 30})
    print("ETL STATS:", r.status_code, r.json())

# %%
test_health()
# Out:
# HEALTH: 200 {'status': 'ok'}

# %%
test_pairs()
# Out:
# PAIRS: 200 [{'pair': 'EUR/USD', 'ticker': 'EURUSD=X', 'context': ['DX-Y.NYB', 'HYG']}, {'pair': 'GBP/USD', 'ticker': 'GBPUSD=X', 'context': ['DX-Y.NYB', 'HYG']}, {'pair': 'USD/JPY', 'ticker': 'JPY=X', 'context': ['^N225', '^TNX']}, {'pair': 'USD/CHF', 'ticker': 'CHF=X', 'context': ['GC=F', 'LQD']}, {'pair': 'AUD/USD', 'ticker': 'AUDUSD=X', 'context': ['^TNX', '^GSPC']}, {'pair': 'USD/CAD', 'ticker': 'CAD=X', 'context': ['DX-Y.NYB', 'BZ=F']}, {'pair': 'NZD/USD', 'ticker': 'NZDUSD=X', 'context': ['^TNX', '^GSPC']}, {'pair': 'EUR/GBP', 'ticker': 'EURGBP=X', 'context': ['NG=F', 'BZ=F']}, {'pair': 'USD/RUB', 'ticker': 'RUB=X', 'context': ['DX-Y.NYB', 'GC=F']}, {'pair': 'EUR/RUB', 'ticker': 'EURRUB=X', 'context': ['^STOXX50E', 'NG=F']}]

# %%
test_history()
# Out:
# HISTORY: 200 [{'ts': '2024-01-01', 'open': 1.10558319, 'high': 1.10533881, 'low': 1.10399652, 'close': 1.10399652}, {'ts': '2024-01-02', 'open': 1.10387456, 'high': 1.10460615, 'low': 1.09419966, 'close': 1.09419966}]

# %%
test_context()
# Out:
# CONTEXT: 200 [{'ts': '2024-01-02', 'ticker': 'DX-Y.NYB', 'close': 102.15000153}, {'ts': '2024-01-03', 'ticker': 'DX-Y.NYB', 'close': 102.45999908}]

# %%
test_predictions()
# Out:
# PREDICTIONS: 200 [{'ts': '2024-12-18', 'realized_vol': 0.003536345313171846, 'predicted_vol': 0.003554014695641392, 'vol_index': 24.267578418167048, 'predicted_index': 24.539886585958463}, {'ts': '2024-12-19', 'realized_vol': 0.003834695889981219, 'predicted_vol': 0.0034723210059176474, 'vol_index': 28.868936509543538, 'predicted_index': 23.283482466470634}]

# %%
test_latest()
# Out:
# LATEST: 200 {'pair': 'EUR/USD', 'last_ts': '2026-05-01', 'last_close': 1.1726079, 'change_pct': -0.035172446435027815, 'realized_vol': 0.003029174832494943, 'predicted_vol': 0.0032008822713917476, 'vol_index': 16.438354374590975, 'predicted_index': 19.14382491913943}

# %%
test_etl_stats()
# Out:
# ETL STATS: 200 [{'job': 'loader', 'status': 'success', 'n': 2, 'last_run': '2026-05-05T11:19:23.740320+00:00'}, {'job': 'predictor', 'status': 'success', 'n': 2, 'last_run': '2026-05-05T11:19:36.141332+00:00'}]
